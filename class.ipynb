# %%
x=[26,13,23,46,80,50,55]

# %%
x.sort()

# %%
print(x)
# Out:
# [13, 23, 26, 46, 50, 55, 80]

# %%
q2=x.index(x[len(x)//2])

# %%
x[0:q2]
# Out:
# [13, 23, 26]

# %%
y=x[:q2//2]
Q1= y[len(y)//2]

# %%
Q1
# Out:
# 13

# %%
q2
# Out:
# 3

# %%
y1=x[q2+1:]
Q3=y1[len(y1)//2]

# %%
x
# Out:
# [13, 23, 26, 46, 50, 55, 80]

# %%
Q3
# Out:
# 55

# %%
IQR=Q3-Q1

# %%
IQR
# Out:
# 42
